# %%
import sklearn.datasets as data
import matplotlib.pyplot as plt
import numpy as np
DEBUGGING = True

# %%
#-generate random data for clustering
STD=2
X, clusters = data.make_blobs( n_samples=1000, n_features=2, cluster_std=STD, random_state=1224 )
# set number of instances
M = len( X )

# plot the above data with differenet std's
plt.figure()
plt.plot(X[:,0], X[:,1], 'b.', markersize=5)
plt.xlim((-15,15))
plt.ylim((-15,15))
plt.title('# of samples=1000, '+'cluster_std='+str(STD))
plt.plot()
# plt.savefig('myfig.png') # save figures for different std's
plt.show()
